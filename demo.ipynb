# %%
from google.colab import drive

drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
cd /content/drive/My Drive/roboflow
# Out:
# /content/drive/My Drive/roboflow

# %%
pip install roboflow

# %%
pip install opencv-python

# %%
from roboflow import Roboflow
import cv2
import time

# Roboflow API anahtarınızı burada tanımlayın
rf = Roboflow(api_key="rtb221FnxMKCd8LrP3Ao")

# Projenizi ve modelinizi seçin
project = rf.workspace().project("volleyball-fvtfx")
model = project.version(1).model

# Video dosyasının adını ve kaydedilecek dizini belirleyin
video_file = "my_video.mp4"
output_directory = "./result/"

# Videoyu açın
cap = cv2.VideoCapture(video_file)

# CSV raporu oluşturmak için başlık satırını yazın
with open("output.csv", "w") as csv_file:
    csv_file.write("Zaman|Ekran Görüntüsü Adı\n")

# Başlangıç zamanını al
start_time = time.time()

# Videonun her bir frame'ini işle
frame_number = 0

# Videoyu işle
while True:
    ret, frame = cap.read()
    if not ret:
        break

    frame_number += 1

    # Modeli kullanarak voleybol topunu tespit et
    results = model.predict(frame)

    # Voleybol topunu tespit edilen kareleri işle
    for result in results:
        class_name = result["class"]
        confidence = result["confidence"]
        bbox = result["x"], result["y"], result["width"], result["height"]
        image_path = result["image_path"]


        if class_name == "Volleyball" and confidence >= 0.7:  # Sadece güvenilir tahminleri alın
          elapsed_time = time.time() - start_time
          timestamp = time.strftime("%H:%M:%S", time.gmtime(elapsed_time))
          screenshot_name = f"result_{int(time.time())}.jpg"
          screenshot_path = f"{output_directory}/{screenshot_name}"

          # Ekran görüntüsünü kaydet
          cv2.imwrite(screenshot_path, image_path)

          # CSV raporuna bilgileri ekleyin
          with open("output.csv", "a") as csv_file:
              csv_file.write(f"{timestamp}|{screenshot_name}\n")

# Temizlik
cap.release()
cv2.destroyAllWindows()

# CSV dosyasını kapat
csv_file.close()
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-20-51c349a92d44> in <cell line: 30>()
#      36
#      37     # Modeli kullanarak voleybol topunu tespit et
# ---> 38     results = model.predict(frame)
#      39
#      40     # Voleybol topunu tespit edilen kareleri işle
#
# /usr/local/lib/python3.10/dist-packages/roboflow/models/object_detection.py in predict(self, image_path, hosted, format, classes, overlap, confidence, stroke, labels)
#     221                 img_str = base64.b64encode(buffer)
#     222                 img_str = img_str.decode("ascii")
# --> 223                 resp = requests.post(
#     224                     self.api_url,
#     225                     data=img_str,
#
# /usr/local/lib/python3.10/dist-packages/requests/api.py in post(url, data, json, **kwargs)
#     113     """
# ...
